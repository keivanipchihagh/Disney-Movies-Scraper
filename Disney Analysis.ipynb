# %% [markdown]
# # Disney Analysis

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ## Load Dataset

# %%
def load_csv(name = 'csv_pickle_disney_movies'):
    return pd.read_csv('datasets/' + name + '.csv')

# %%
df = load_csv()

# %%
df.head()
# Out:
#    Unnamed: 0                            title  \
# 0           0         Academy Award Review of
# 1           1  Snow White and the Seven Dwarfs
# 2           2                        Pinocchio
# 3           3                         Fantasia
# 4           4             The Reluctant Dragon
#
#                                            Cover Url       Production company  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...  Walt Disney Productions
# 1  https://upload.wikimedia.org/wikipedia/en/thum...  Walt Disney Productions
# 2  https://upload.wikimedia.org/wikipedia/en/thum...  Walt Disney Productions
# 3  https://upload.wikimedia.org/wikipedia/en/thum...  Walt Disney Productions
# 4  https://upload.wikimedia.org/wikipedia/en/thum...  Walt Disney Productions
#
#           Release date  Running time        Country Language    Box office  \
# 0  1937-05-19 00:00:00          41.0  United States  English  4.547200e+01
# 1  1937-12-21 00:00:00          83.0  United States  English  4.180000e+08
# 2  1940-02-07 00:00:00          88.0  United States  English  1.640000e+08
# 3  1940-11-13 00:00:00         126.0  United States  English  7.640000e+01
# 4  1941-06-20 00:00:00          74.0  United States  English  9.600000e+05
#
#                                                  url  ...  \
# 0  https://en.wikipedia.org//wiki/Academy_Award_R...  ...
# 1  https://en.wikipedia.org//wiki/Snow_White_and_...  ...
# 2  https://en.wikipedia.org//wiki/Pinocchio_(1940...  ...
# 3  https://en.wikipedia.org//wiki/Fantasia_(1940_...  ...
# 4  https://en.wikipedia.org//wiki/The_Reluctant_D...  ...
#
#                                    Music by      Distributed by  \
# 0                                       NaN                 NaN
# 1  Frank Churchill,Paul Smith,Leigh Harline  RKO Radio Pictures
# 2                Leigh HarlinePaul J. Smith  RKO Radio Pictures
# 3                               See program  RKO Radio Pictures
# 4                Frank ChurchillLarry Morey  RKO Radio Pictures
#
#                                             Story by   Narrated by  \
# 0                                                NaN           NaN
# 1                                                NaN           NaN
# 2  Ted SearsOtto EnglanderWebb SmithWilliam Cottr...           NaN
# 3                              Joe Grant,Dick Huemer  Deems Taylor
# 4                                                NaN           NaN
#
#     Cinematography        Edited by Languages Screenplay by Countries  \
# 0              NaN              NaN       NaN           NaN       NaN
# 1              NaN              NaN       NaN           NaN       NaN
# 2              NaN              NaN       NaN           NaN       NaN
# 3  James Wong Howe              NaN       NaN           NaN       NaN
# 4     Bert Glennon  Paul Weatherwax       NaN           NaN       NaN
#
#   Production companies
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 34 columns]

# %% [markdown]
# ## Cleaning up

# %%
# Remove the 'Unnamed' column
df.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
# Remove 'Production company' and 'Production companies' column, cause we already know the company, duh
df.drop(columns = ['Production company', 'Production companies'], inplace = True)

# %%
# Remove 'Languages' column due to being obvious that it's primary in English
df.drop(columns = ['Languages'], inplace = True)

# %%
# Since Amazon posters make more sense, 'Cover Url' column should be removed
df.drop(columns = ['Cover Url'], inplace = True)

# %%
# Remove the 'URL' column since we don't need it anymore
df.drop(columns = ['url'], inplace = True)

# %%
# Remove columns 'Narrated by', 'Languages' and 'Countries' since they have very few records
df.drop(columns = ['Narrated by', 'Countries', 'Story by'], inplace = True)

# %%
# Rename columns
df = df.rename(columns = {'Written by': 'Writer(s)', 
                          'Produced by': 'Producer(s)', 
                          'Directed by': 'Director(s)', 
                          'Starring': 'Actors', 
                          'Running time': 'Duration',
                          'title': 'Title',
                         })

# %%
df.head()
# Out:
#                              Title         Release date  Duration  \
# 0         Academy Award Review of   1937-05-19 00:00:00      41.0
# 1  Snow White and the Seven Dwarfs  1937-12-21 00:00:00      83.0
# 2                        Pinocchio  1940-02-07 00:00:00      88.0
# 3                         Fantasia  1940-11-13 00:00:00     126.0
# 4             The Reluctant Dragon  1941-06-20 00:00:00      74.0
#
#          Country Language    Box office     Budget Rotten Tomatoes  IMDB  \
# 0  United States  English  4.547200e+01        NaN             NaN   7.1
# 1  United States  English  4.180000e+08  1490000.0             NaN   7.6
# 2  United States  English  1.640000e+08  2600000.0             73%   7.4
# 3  United States  English  7.640000e+01  2280000.0             95%   7.7
# 4  United States  English  9.600000e+05   600000.0             67%   6.9
#
#    Metascore  ...                                        Director(s)  \
# 0        NaN  ...                                                NaN
# 1       95.0  ...  David Hand ,William Cottrell,Wilfred Jackson,L...
# 2       99.0  ...  Supervising DirectorsBen SharpsteenHamilton Lu...
# 3       96.0  ...  Samuel Armstrong,James Algar,Bill Roberts,Paul...
# 4        NaN  ...  Alfred Werker Hamilton Luske Jack Cutting, Ub ...
#
#                   Producer(s)  \
# 0                         NaN
# 1                 Walt Disney
# 2                 Walt Disney
# 3  Walt Disney,Ben Sharpsteen
# 4                 Walt Disney
#
#                                            Writer(s)  \
# 0                                                NaN
# 1  Ted Sears,Richard Creedon,Otto Englander,Dick ...
# 2                                                NaN
# 3                                                NaN
# 4  Live-action:Ted SearsAl PerkinsLarry ClemmonsB...
#
#                                       Based on  \
# 0                                          NaN
# 1              Snow Whiteby The Brothers Grimm
# 2  The Adventures of Pinocchioby Carlo Collodi
# 3                                          NaN
# 4                                          NaN
#
#                                               Actors  \
# 0                                                NaN
# 1  Adriana Caselotti,Lucille La Verne,Harry Stock...
# 2  Cliff Edwards,Dickie Jones,Christian Rub,Walte...
# 3                     Leopold Stokowski,Deems Taylor
# 4  Robert BenchleyFrances GiffordBuddy PepperNana...
#
#                                    Music by      Distributed by  \
# 0                                       NaN                 NaN
# 1  Frank Churchill,Paul Smith,Leigh Harline  RKO Radio Pictures
# 2                Leigh HarlinePaul J. Smith  RKO Radio Pictures
# 3                               See program  RKO Radio Pictures
# 4                Frank ChurchillLarry Morey  RKO Radio Pictures
#
#     Cinematography        Edited by Screenplay by
# 0              NaN              NaN           NaN
# 1              NaN              NaN           NaN
# 2              NaN              NaN           NaN
# 3  James Wong Howe              NaN           NaN
# 4     Bert Glennon  Paul Weatherwax           NaN
#
# [5 rows x 25 columns]
